# %%
# Shopping Cart system (Using Python list)
# A shopping cart system stores products selected by customers.
# products are stored in order.
# New items can be added.
# items can be removed.

# %%
cart = [] # Empty list for storing products.
# Adding products
cart.append("Laptop")
cart.append("Mobile")
cart.append("Headphones")
print("Items in cart: ")
for item in cart:
    print(item)
# Removing products
cart.remove("Mobile")
print("\nAfter removing Mobile:")
for item in cart:
    print(item)
# total number of items
print("\nTotal items:",len(cart))
# Out:
# Items in cart:
# Laptop
# Mobile
# Headphones
#
# After removing Mobile:
# Laptop
# Headphones
#
# Total items: 2

# %%
# Student Management System using list + Dictionary
students = []
#Adding student details
student1 = {
        "Name": "Rahul",
        "Marks": 85,
        "Attendance": "90%"
}
student2 = {
        "Name": "Priya",
        "Marks": 92,
        "Attendance": "95%"
}
students.append(student1)
students.append(student2)
print("Student Records:")
for student in students:
    print("------------------")
    print("Name:",student["Name"])
    print("Marks:",student["Marks"])
    print("Attendance:",student["Attendance"])
# Out:
# Student Records:
# ------------------
# Name: Rahul
# Marks: 85
# Attendance: 90%
# ------------------
# Name: Priya
# Marks: 92
# Attendance: 95%

# %%
fruits = []
fruits.append("Apple")
fruits.append("Banana")
fruits.append("Cherry")
fruits.append("Orange")
fruits.append("Watermilon")
print("Fruits are")
for fruit in fruits:
    print(fruit)
fruits.remove("Cherry")
print("\nAfter Removing items are:")
for fruit in fruits:
    print(fruit)
fruits.insert(1,"Mango")
print("\nAfter Adding items are:")
for fruit in fruits:
    print(fruit)
print("Total fruits are:",len(fruits))
# Out:
# Fruits are
# Apple
# Banana
# Cherry
# Orange
# Watermilon
#
# After Removing items are:
# Apple
# Banana
# Orange
# Watermilon
#
# After Adding items are:
# Apple
# Mango
# Banana
# Orange
# Watermilon
# Total fruits are: 5

# %%
# E-commerce Website (Python Project)
products = [
        {"id": 1, "Name": "Laptop", "Price": 50000},
        {"id": 2, "Name": "Mobile", "Price": 20000},
        {"id": 3, "Name": "headphones", "Price": 2000}
]
cart = []
cart.append(products[0])
cart.append(products[1])
print("Shopping Cart:")
total = 0
for item in cart:
    print(item["Name"], "-", item["Price"])
    total += item["Price"]
print("Total Amount:",total)
order = {
       "Customer": "rahul",
        "Items": cart,
        "Amount": total
}
print("\nOrder Details:")
print(order)
# Out:
# Shopping Cart:
# Laptop - 50000
# Mobile - 20000
# Total Amount: 70000
#
# Order Details:
# {'Customer': 'rahul', 'Items': [{'id': 1, 'Name': 'Laptop', 'Price': 50000}, {'id': 2, 'Name': 'Mobile', 'Price': 20000}], 'Amount': 70000}

# %%
# Social Media App
user = {
      "user_name": "sana",
      "Posts": [],
      "Followers": set()
}
# Adding posts
user["Posts"].append("My first post!".title())
user["Posts"].append("Learning python".title())
# Adding Followers
user["Followers"].add("Amit")
user["Followers"].add("Priya")
user["Followers"].add("Rahul")
user["Followers"].add("Amit") # Duplicates are removed
# Comments
comments = [
       "Nice Post!",
       "Great Work!"
]
# display data
print("user:", user["user_name"])
print("\nposts:")
for post in user["Posts"]:
    print(post)
print("\nFollowers:")
print(user["Followers"])
print("\nComments")
print(comments)
# Out:
# user: sana
#
# posts:
# My First Post!
# Learning Python
#
# Followers:
# {'Rahul', 'Amit', 'Priya'}
#
# Comments
# ['Nice Post!', 'Great Work!']

# %%
# GPS/MAP Application using tuple
location = (12.9716, 77.5964)
print("gps".upper(), "location".title())
print("latitude:".title(),location[0])
print("logitude:".title(),location[1])
# Out:
# GPS Location
# Latitude: 12.9716
# Logitude: 77.5964

# %%
class Node:
    def __init__(self, data=None):
        self.data = data
        self.next = None

class CircularList:
    def __init__(self, data=None):
        self.head = None
        self.tail = None
        self.size = 0

    def clear(self):
        self.tail = None
        self.head = None

    def append(self, data):
        node = Node(data)
        if self.head:
            self.head.next = node
            self.head = node
        else:
            self.head = node
            self.tail = node
        self.head.next = self.tail
        self.size += 1

    def delete(self, data):
        current = self.tail
        prev = self.tail
        while prev == current or prev != self.head:
            if current.data == data:
                if current == self.tail:
                    self.tail = current.next
                    self.head.next = self.tail
                else:
                    prev.next = current.next
                self.size -= 1
                return
            prev = current
            current = current.next

    def iter(self):
        current = self.tail
        while current:
            val = current.data
            current = current.next
            yield val

words = CircularList()
words.append('eggs')
words.append('ham')
words.append('spam')

counter = 0
for word in words.iter():
    print(word)
    counter += 1
    if counter > 1000:
        break

import sys
sys.exit()

l.append('foo')
l.append('bar')
l.append('bim')
l.append('baz')
l.append('quux')
l.append('duux')

counter = 0
for item in l.iter():
    print(item)
    counter += 1
    if counter > 1000:
        break

print("Done iterating. Now we try to delete something that isn't there.")
l.delete('socks')
print('back to iterating')
counter = 0
for item in l.iter():
    print(item)
    counter += 1
    if counter > 1000:
        break

print('Let us delete something that is there.')
l.delete('foo')
print('back to iterating')
counter = 0
for item in l.iter():
    print(item)
    counter += 1
    if counter > 1000:
        break
# Out:
# eggs
# ham
# spam
# eggs
# ham
# spam
# eggs
# ham
# spam
# eggs
# ham
# spam
# eggs
# ham
# spam
# eggs
# ham
# spam
# eggs
# ham
# spam
# eggs
# ham
# spam
# eggs
# ham
# spam
# eggs
# ham
# spam
# eggs
# ham
# spam
# eggs
# ham
# spam
# eggs
# ham
# spam
# eggs
# ham
# spam
# eggs
# ham
# spam
# eggs
# ham
# spam
# eggs
# ham
# spam
# eggs
# ham
# spam
# eggs
# ham
# spam
# eggs
# ham
# spam
# eggs
# ham
# spam
# eggs
# ham
# spam
# eggs
# ham
# spam
# eggs
# ham
# spam
# eggs
# ham
# spam
# eggs
# ham
# spam
# eggs
# ham
# spam
# eggs
# ham
# spam
# eggs
# ham
# spam
# eggs
# ham
# spam
# eggs
# ham
# spam
# eggs
# ham
# spam
# eggs
# ham
# spam
# eggs
# ham
# spam
# eggs
# ham
# spam
# eggs
# ham
# spam
# eggs
# ham
# spam
# eggs
# ham
# spam
# eggs
# ham
# spam
# eggs
# ham
# spam
# eggs
# ham
# spam
# eggs
# ham
# spam
# eggs
# ham
# spam
# eggs
# ham
# spam
# eggs
# ham
# spam
# eggs
# ham
# spam
# eggs
# ham
# spam
# eggs
# ham
# spam
# eggs
# ham
# spam
# eggs
# ham
# spam
# ...

# %%
# Customer Support Chatbot (OOps)
class chatbot:
    def __init__(self,name):
        self.name = name
        self.history = []
    def get_response(self, message):
        message = message.lower()
        if "hello" in message:
            return "Hello! How can I help you?"
        elif "price" in message:
            return "Plece check our product pricing page."
        elif "Order" in message:
            return "Tell me your order Id."
        elif "bye" in message:
            return "Thank you. Have a nice day!"
        else:
            return "sorry, I don't understand."
    def chat(self, user_name):
        response = self.get_response(user_message)
        self.history.append(
          {
              "user": user_msessage,
              "bot" : response
          }
        )
        return response
bot = chatbot("SupportBot")
while True:
    user = input("You: ")
    if user.lower() == "exit":
        break
        
    print("Bot: ", bot.chat(user))
# Out:
# You:  hello
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 33
#      30 if user.lower() == "exit":
#      31     break
# ---> 33 print("Bot: ", bot.chat(user))
#
# Cell In[41], line 19, in chatbot.chat(self, user_name)
#      18 def chat(self, user_name):
# ---> 19     response = self.get_response(user_message)
#      20     self.history.append(
#      21       {
#      22           "user": user_msessage,
#      23           "bot" : response
#      24       }
#      25     )
#      26     return response
#
# NameError: name 'user_message' is not defined

# %%
# Student performance prediction
# Goal : Predict student marks based on study hours.
# Concepets:
# Data Cleaning
# Liner Regression
# Model Training
# Prediction

# %%
# install:
pip install pandas scikit-learn matplotlib
# Out:
#   Cell In[43], line 2
#     pip install pandas scikit-learn matplotlib
#         ^
# SyntaxError: invalid syntax

# %%
pip install pandas scikit-learn matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
# dataset
data = {
       "Study_hours" : [2,3,5,7,8,10],
       "marks":[40,50,65,75,85,95]
}
df = pd.DataFrame(data)
# input and output
x = df[["study_hours"]]
y = df["marks"]
# split data
x_train,x_test,y_train,y_test = train_test_split(
      x,y,test_size = 0.2
)
# create model
model = LinearRegression()
# Train
model.fit(
    x_train,
    y_train
)
# prediction
hours = [[6]]
prediction = model.predict(hours)
print("predicted marks:",prediction[0])
